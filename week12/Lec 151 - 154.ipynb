# %% [markdown]
# # Lec 151 - Base Code

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()
G.add_nodes_from(range(0, 50))
nx.draw(G, with_labels=True, node_color='red', node_size=500, font_size=10, font_color='black', font_weight='bold')

# %% [markdown]
# # Lec 152 to 154 - Programming
